# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import seaborn as sns
import warnings
warnings. filterwarnings ('ignore')

# %%
da=pd.read_excel('NASA - Nearest Earth Objects.ipynb.xlsx')
da
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 1              0.265800          0.594347        73588.72666   6.143813e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 3              0.096506          0.215794        24764.30314   2.543497e+07
# 4              0.255009          0.570217        42737.73376   4.627557e+07
# ...                 ...               ...                ...            ...
# 49995          0.069913          0.156329        47138.67659   7.405003e+06
# 49996          0.027833          0.062236        25473.91164   9.815503e+06
# 49997          0.018389          0.041119        31292.07193   4.222328e+06
# 49998          0.016016          0.035813        41711.26262   5.777209e+06
# 49999          0.016016          0.035813        41711.26262   5.777209e+06
#
# ...

# %%
da.head()
# Out:
#    est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0          1.198271          2.679415        13569.24922    54839744.08
# 1          0.265800          0.594347        73588.72666    61438126.52
# 2          0.722030          1.614507       114258.69210    49798724.94
# 3          0.096506          0.215794        24764.30314    25434972.72
# 4          0.255009          0.570217        42737.73376    46275567.00
#
#   orbiting_body  sentry_object  absolute_magnitude  hazardous
# 0         Earth          False               16.73      False
# 1         Earth          False               20.00       True
# 2         Earth          False               17.83      False
# 3         Earth          False               22.20      False
# 4         Earth          False               20.09       True

# %%
da.tail()
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 49995          0.069913          0.156329        47138.67659    7405002.921
# 49996          0.027833          0.062236        25473.91164    9815503.350
# 49997          0.018389          0.041119        31292.07193    4222327.730
# 49998          0.016016          0.035813        41711.26262    5777208.975
# 49999          0.016016          0.035813        41711.26262    5777208.975
#
#       orbiting_body  sentry_object  absolute_magnitude  hazardous
# 49995         Earth          False                22.9      False
# 49996         Earth          False                24.9      False
# 49997         Earth          False                25.8      False
# 49998         Earth          False                26.1      False
# 49999         Earth          False                26.1      False

# %%
da.shape
# Out:
# (50000, 8)

# %%
da.size
# Out:
# 400000

# %%
da.columns
# Out:
# Index(['est_diameter_min', 'est_diameter_max', 'relative_velocity',
#        'miss_distance', 'orbiting_body', 'sentry_object', 'absolute_magnitude',
#        'hazardous'],
#       dtype='object')

# %%
da.dtypes
# Out:
# est_diameter_min      float64
# est_diameter_max      float64
# relative_velocity     float64
# miss_distance         float64
# orbiting_body          object
# sentry_object            bool
# absolute_magnitude    float64
# hazardous                bool
# dtype: object

# %%
da.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   est_diameter_min    50000 non-null  float64
#  1   est_diameter_max    50000 non-null  float64
#  2   relative_velocity   50000 non-null  float64
#  3   miss_distance       50000 non-null  float64
#  4   orbiting_body       50000 non-null  object
#  5   sentry_object       50000 non-null  bool
#  6   absolute_magnitude  50000 non-null  float64
#  7   hazardous           50000 non-null  bool
# dtypes: bool(2), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
da.isnull().sum()
# Out:
# est_diameter_min      0
# est_diameter_max      0
# relative_velocity     0
# miss_distance         0
# orbiting_body         0
# sentry_object         0
# absolute_magnitude    0
# hazardous             0
# dtype: int64

# %%
da.duplicated().sum()
# Out:
# np.int64(10)

# %%
da=da.drop_duplicates()
da
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 1              0.265800          0.594347        73588.72666   6.143813e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 3              0.096506          0.215794        24764.30314   2.543497e+07
# 4              0.255009          0.570217        42737.73376   4.627557e+07
# ...                 ...               ...                ...            ...
# 49994          0.010582          0.023661        85436.85160   5.947157e+07
# 49995          0.069913          0.156329        47138.67659   7.405003e+06
# 49996          0.027833          0.062236        25473.91164   9.815503e+06
# 49997          0.018389          0.041119        31292.07193   4.222328e+06
# 49998          0.016016          0.035813        41711.26262   5.777209e+06
#
# ...

# %%
da['orbiting_body'].unique()
# Out:
# array(['Earth'], dtype=object)

# %%
da['sentry_object'].unique()
# Out:
# array([False])

# %%
da['hazardous'].unique()
# Out:
# array([False,  True])

# %%
da['orbiting_body'].value_counts()
# Out:
# orbiting_body
# Earth    49990
# Name: count, dtype: int64

# %%
da['sentry_object'].value_counts()
# Out:
# sentry_object
# False    49990
# Name: count, dtype: int64

# %%
da['hazardous'].value_counts()
# Out:
# hazardous
# False    44497
# True      5493
# Name: count, dtype: int64

# %%
data=da.select_dtypes(include=['number'])
data
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 1              0.265800          0.594347        73588.72666   6.143813e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 3              0.096506          0.215794        24764.30314   2.543497e+07
# 4              0.255009          0.570217        42737.73376   4.627557e+07
# ...                 ...               ...                ...            ...
# 49994          0.010582          0.023661        85436.85160   5.947157e+07
# 49995          0.069913          0.156329        47138.67659   7.405003e+06
# 49996          0.027833          0.062236        25473.91164   9.815503e+06
# 49997          0.018389          0.041119        31292.07193   4.222328e+06
# 49998          0.016016          0.035813        41711.26262   5.777209e+06
#
#        absolute_magnitude
# 0                   16.73
# ...

# %%
da.describe()
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# count      49990.000000      49990.000000       49990.000000   4.999000e+04
# mean           0.142185          0.317934       49486.729488   4.003152e+07
# std            0.337070          0.753712       25616.244978   2.144500e+07
# min            0.000609          0.001362         561.695602   1.185167e+04
# 25%            0.021113          0.047211       29694.342330   2.245330e+07
# 50%            0.055533          0.124177       45968.343925   4.154650e+07
# 75%            0.163891          0.366471       64691.719745   5.868667e+07
# max           37.892650         84.730541      193386.975200   7.479655e+07
#
#        absolute_magnitude
# count        49990.000000
# mean            23.290814
# std              2.941422
# min              9.230000
# 25%             21.050000
# 50%             23.400000
# 75%             25.500000
# max             33.200000

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(da)   
plt.show()

# %%
x=da['est_diameter_min']
plt.hist(x)
plt.show()

# %%
x=da['est_diameter_max']
plt.hist(x)
plt.show()

# %%
x=da['relative_velocity']
plt.hist(x)
plt.show()

# %%
x=da['miss_distance']
plt.hist(x)
plt.show()

# %%
x=da['absolute_magnitude']
plt.hist(x)
plt.show()

# %%
sns.boxplot(da)
# Out:
# <Axes: >

# %%
sns.boxplot(da['est_diameter_min'])
# Out:
# <Axes: ylabel='est_diameter_min'>

# %%
Q1=da['est_diameter_min'].quantile(0.25)
Q3=da['est_diameter_min'].quantile(0.75)
Q1, Q3
# Out:
# (np.float64(0.021113245), np.float64(0.163890952))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(0.142777707)

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (np.float64(-0.1930533155), np.float64(0.37805751249999997))

# %%
da.loc[(da['est_diameter_min']<lower_limit)|(da['est_diameter_min']>upper_limit)]
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 15             0.483676          1.081534        74576.93076   5.988081e+07
# 19             0.461907          1.032856       104810.09370   1.883284e+07
# 25             0.441118          0.986370        69871.97731   5.843872e+07
# ...                 ...               ...                ...            ...
# 49861          0.506471          1.132505        76325.19978   2.218994e+06
# 49913          0.555335          1.241767        23162.83411   5.636220e+07
# 49937          0.490405          1.096579        62095.77071   5.980855e+07
# 49938          0.722030          1.614507        25140.78128   7.451789e+07
# 49989          3.408435          7.621492        36410.22428   1.964714e+07
#
# ...

# %%
new_data=da.loc[(data['est_diameter_min']<=upper_limit) & (da['est_diameter_min'] >= lower_limit)]
print('before removing outliers:',len(da))
print('after removing outliers:',len(new_data))
print('outliers:',len(da)-len(new_data))
# Out:
# before removing outliers: 49990
# after removing outliers: 45787
# outliers: 4203

# %%
sns.boxplot(new_data['est_diameter_min'])
# Out:
# <Axes: ylabel='est_diameter_min'>

# %%
sns.boxplot(da['est_diameter_max'])
# Out:
# <Axes: ylabel='est_diameter_max'>

# %%
Q1=da['est_diameter_max'].quantile(0.25)
Q3=da['est_diameter_max'].quantile(0.75)
Q1, Q3
# Out:
# (np.float64(0.04721065), np.float64(0.366471308))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(0.319260658)

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (np.float64(-0.43168033699999997), np.float64(0.8453622949999999))

# %%
da.loc[(da['est_diameter_max']<lower_limit)|(da['est_diameter_max']>upper_limit)]
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 15             0.483676          1.081534        74576.93076   5.988081e+07
# 19             0.461907          1.032856       104810.09370   1.883284e+07
# 25             0.441118          0.986370        69871.97731   5.843872e+07
# ...                 ...               ...                ...            ...
# 49861          0.506471          1.132505        76325.19978   2.218994e+06
# 49913          0.555335          1.241767        23162.83411   5.636220e+07
# 49937          0.490405          1.096579        62095.77071   5.980855e+07
# 49938          0.722030          1.614507        25140.78128   7.451789e+07
# 49989          3.408435          7.621492        36410.22428   1.964714e+07
#
# ...

# %%
new_data=da.loc[(data['est_diameter_max']<=upper_limit) & (da['est_diameter_max'] >= lower_limit)]
print('before removing outliers:',len(da))
print('after removing outliers:',len(new_data))
print('outliers:',len(da)-len(new_data))
# Out:
# before removing outliers: 49990
# after removing outliers: 45787
# outliers: 4203

# %%
sns.boxplot(new_data['est_diameter_max'])
# Out:
# <Axes: ylabel='est_diameter_max'>

# %%
sns.boxplot(da['relative_velocity'])
# Out:
# <Axes: ylabel='relative_velocity'>

# %%
Q1=da['relative_velocity'].quantile(0.25)
Q3=da['relative_velocity'].quantile(0.75)
Q1, Q3
# Out:
# (np.float64(29694.34233), np.float64(64691.719745))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(34997.377415)

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (np.float64(-22801.723792500008), np.float64(117187.7858675))

# %%
da.loc[(da['relative_velocity']<lower_limit)|(da['relative_velocity']>upper_limit)]
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 51             1.024601          2.291079        133569.0448    59192889.51
# 53             0.334622          0.748238        178961.5176    70621103.50
# 68             0.152952          0.342011        138119.6179    42449777.79
# 70             0.284810          0.636854        121698.2652    14343696.10
# 97             0.876103          1.959025        167372.8035    73659764.57
# ...                 ...               ...                ...            ...
# 49590          0.413576          0.924783        137385.2769    35368586.49
# 49591          0.124898          0.279280        122567.2756    56639669.71
# 49746          0.441118          0.986370        120743.3014    50753920.56
# 49749          0.175612          0.392681        126542.3385    34721447.77
# 49860          0.218049          0.487573        118908.6541    43243594.44
#
# ...

# %%
new_da=da.loc[(da['relative_velocity']<=upper_limit) & (da['relative_velocity'] >= lower_limit)]
print('before removing outliers:',len(da))
print('after removing outliers:',len(new_data))
print('outliers:',len(da)-len(new_data))
# Out:
# before removing outliers: 49990
# after removing outliers: 45787
# outliers: 4203

# %%
sns.boxplot(new_data['relative_velocity'])
# Out:
# <Axes: ylabel='relative_velocity'>

# %%
sns.boxplot(da['absolute_magnitude'])
# Out:
# <Axes: ylabel='absolute_magnitude'>

# %%
Q1=da['absolute_magnitude'].quantile(0.25)
Q3=da['absolute_magnitude'].quantile(0.75)
Q1, Q3
# Out:
# (np.float64(21.05), np.float64(25.5))

# %%
IQR=Q3-Q1
IQR
# Out:
# np.float64(4.449999999999999)

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (np.float64(14.375000000000002), np.float64(32.175))

# %%
da.loc[(da['absolute_magnitude']<lower_limit)|(da['absolute_magnitude']>upper_limit)]
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 1041           4.576727         10.233872        39643.36305   4.457789e+07
# 1608           4.576727         10.233872        27698.19439   5.214054e+07
# 4020           4.174024          9.333402        71441.25505   5.472822e+07
# 5105           4.174024          9.333402        71693.52419   6.636055e+07
# 10768          3.602093          8.054526        68742.44720   3.940022e+07
# 12709         23.043847         51.527608        15884.25262   5.468808e+07
# 16895          8.640820         19.321462        96530.77489   7.402691e+07
# 18402          4.619075         10.328565        50104.59217   4.942800e+07
# 18822          3.967848          8.872377        60358.50259   5.680503e+07
# 19409          5.230642         11.696071        78537.19438   7.364985e+07
# 21460          8.101305         18.115068        32852.59879   4.286086e+07
# ...

# %%
new_data=da.loc[(da['absolute_magnitude']<=upper_limit) & (da['absolute_magnitude'] >= lower_limit)]
print('before removing outliers:',len(da))
print('after removing outliers:',len(new_data))
print('outliers:',len(da)-len(new_data))
new_data
# Out:
# before removing outliers: 49990
# after removing outliers: 49958
# outliers: 32
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 1              0.265800          0.594347        73588.72666   6.143813e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 3              0.096506          0.215794        24764.30314   2.543497e+07
# 4              0.255009          0.570217        42737.73376   4.627557e+07
# ...                 ...               ...                ...            ...
# 49994          0.010582          0.023661        85436.85160   5.947157e+07
# 49995          0.069913          0.156329        47138.67659   7.405003e+06
# 49996          0.027833          0.062236        25473.91164   9.815503e+06
# 49997          0.018389          0.041119        31292.07193   4.222328e+06
# ...

# %%
sns.boxplot(new_data['absolute_magnitude'])
# Out:
# <Axes: ylabel='absolute_magnitude'>

# %%
new_data
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 1              0.265800          0.594347        73588.72666   6.143813e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 3              0.096506          0.215794        24764.30314   2.543497e+07
# 4              0.255009          0.570217        42737.73376   4.627557e+07
# ...                 ...               ...                ...            ...
# 49994          0.010582          0.023661        85436.85160   5.947157e+07
# 49995          0.069913          0.156329        47138.67659   7.405003e+06
# 49996          0.027833          0.062236        25473.91164   9.815503e+06
# 49997          0.018389          0.041119        31292.07193   4.222328e+06
# 49998          0.016016          0.035813        41711.26262   5.777209e+06
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le1=LabelEncoder()
new_data['orbiting_body']=le1.fit_transform(new_data['orbiting_body'])
new_data
# Out:
#        est_diameter_min  est_diameter_max  relative_velocity  miss_distance  \
# 0              1.198271          2.679415        13569.24922   5.483974e+07
# 1              0.265800          0.594347        73588.72666   6.143813e+07
# 2              0.722030          1.614507       114258.69210   4.979872e+07
# 3              0.096506          0.215794        24764.30314   2.543497e+07
# 4              0.255009          0.570217        42737.73376   4.627557e+07
# ...                 ...               ...                ...            ...
# 49994          0.010582          0.023661        85436.85160   5.947157e+07
# 49995          0.069913          0.156329        47138.67659   7.405003e+06
# 49996          0.027833          0.062236        25473.91164   9.815503e+06
# 49997          0.018389          0.041119        31292.07193   4.222328e+06
# 49998          0.016016          0.035813        41711.26262   5.777209e+06
#
# ...

# %%
x=new_data.drop(['hazardous'],axis=1)
y=new_data['hazardous']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler
sd=MinMaxScaler()
x_train=sd.fit_transform(x_train)
x_test=sd.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False,  True, False], shape=(24979,))

# %%
knn.score(x_train,y_train)
# Out:
# 0.9325033027743305

# %%
knn.score(x_test,y_test)
# Out:
# 0.8806597541935226

# %%
y_test
# Out:
# 7836     False
# 2356     False
# 1030     False
# 16181     True
# 49487    False
#          ...
# 8365     False
# 8634     False
# 40515    False
# 18419    False
# 13423    False
# Name: hazardous, Length: 24979, dtype: bool

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 88.06597541935226

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.95      0.93     22251
#         True       0.44      0.33      0.38      2728
#
#     accuracy                           0.88     24979
#    macro avg       0.68      0.64      0.66     24979
# weighted avg       0.87      0.88      0.87     24979

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
svc=SVC()
svc.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=svc.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
svc.score(x_train,y_train)
# Out:
# 0.8964330037231274

# %%
svc.score(x_test,y_test)
# Out:
# 0.8978742143400457

# %%
y_test
# Out:
# 7836     False
# 2356     False
# 1030     False
# 16181     True
# 49487    False
#          ...
# 8365     False
# 8634     False
# 40515    False
# 18419    False
# 13423    False
# Name: hazardous, Length: 24979, dtype: bool

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 89.78742143400457

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      1.00      0.95     22251
#         True       0.84      0.08      0.15      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.87      0.54      0.55     24979
# weighted avg       0.89      0.90      0.86     24979

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
log.score(x_train,y_train)
# Out:
# 0.8897473878057568

# %%
log.score(x_test,y_test)
# Out:
# 0.8903078586012251

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 89.0307858601225

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      0.99      0.94     22251
#         True       0.47      0.04      0.07      2728
#
#     accuracy                           0.89     24979
#    macro avg       0.68      0.52      0.51     24979
# weighted avg       0.85      0.89      0.85     24979

# %%
from sklearn.naive_bayes import GaussianNB
gb=GaussianNB()
gb.fit(x_train,y_train)
y_pred=gb.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False,  True], shape=(24979,))

# %%
y_pred=gb.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False,  True], shape=(24979,))

# %%
gb.score(x_train,y_train)
# Out:
# 0.8347812162216262

# %%
gb.score(x_test,y_test)
# Out:
# 0.8410264622282717

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 84.10264622282718

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.91      0.91     22251
#         True       0.28      0.29      0.28      2728
#
#     accuracy                           0.84     24979
#    macro avg       0.60      0.60      0.60     24979
# weighted avg       0.84      0.84      0.84     24979

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
dt.score(x_test,y_test)
# Out:
# 0.8767364586252452

# %%
print(classification_report(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.93      0.93     22251
#         True       0.44      0.44      0.44      2728
#
#     accuracy                           0.88     24979
#    macro avg       0.68      0.68      0.68     24979
# weighted avg       0.88      0.88      0.88     24979
#
# ...

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 87.67364586252452

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 47,random_state=34)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
# Out:
# 0.9026382161015253

# %%
y_pred=gb.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False,  True], shape=(24979,))

# %%
rf.score(x_train,y_train)
# Out:
# 0.9997998318587613

# %%
rf.score(x_test,y_test)
# Out:
# 0.9026382161015253

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 84.10264622282718

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.91      0.91     22251
#         True       0.28      0.29      0.28      2728
#
#     accuracy                           0.84     24979
#    macro avg       0.60      0.60      0.60     24979
# weighted avg       0.84      0.84      0.84     24979

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost=AdaBoostClassifier(n_estimators=50,estimator=None,learning_rate=0.3,random_state=1)

# %%
adaboost.fit(x_train,y_train)
y_pred=adaboost.predict(x_train)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
adaboost.score(x_train,y_train)
# Out:
# 0.889427118779775

# %%
adaboost.score(x_test,y_test)
# Out:
# 0.8907882621401978

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 89.07882621401978

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      1.00      0.94     22251
#         True       0.00      0.00      0.00      2728
#
#     accuracy                           0.89     24979
#    macro avg       0.45      0.50      0.47     24979
# weighted avg       0.79      0.89      0.84     24979

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(n_estimators=200,learning_rate=0.05, random_state=100) 
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=200,
#                            random_state=100)

# %%
y_pred=gbc.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
gbc.score(x_train,y_train)
# Out:
# 0.9038392249489571

# %%
gbc.score(x_test,y_test)
# Out:
# 0.902237879819048

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.2237879819048

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.99      0.95     22251
#         True       0.76      0.15      0.26      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.83      0.57      0.60     24979
# weighted avg       0.89      0.90      0.87     24979

# %%
# !pip install xgboost
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(x_train,y_train)
# Out:
# ...
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=gbc.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
xgb.score(x_train,y_train)
# Out:
# 0.9370271027663237

# %%
xgb.score(x_test,y_test)
# Out:
# 0.9023179470755435

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.2237879819048

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.99      0.95     22251
#         True       0.76      0.15      0.26      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.83      0.57      0.60     24979
# weighted avg       0.89      0.90      0.87     24979

# %%
sns.countplot(x='hazardous',data=new_data)
# Out:
# <Axes: xlabel='hazardous', ylabel='count'>

# %%
# !pip install -U xgboost lightgbm imbalanced-learn mlxtend
from imblearn.over_sampling import SMOTE
over = SMOTE(random_state=2)
x_os, y_os = over.fit_resample(x, y)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'n_neighbors':[3,5,7,9],'weights':['uniform','distance']}
cls=GridSearchCV(knn,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=KNeighborsClassifier(n_neighbors=3),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
print(cls.best_params_)
# Out:
# {'n_neighbors': 9, 'weights': 'uniform'}

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3,weights='distance')
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3, weights='distance')

# %%
y_pred=knn.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False,  True, False], shape=(24979,))

# %%
knn.score(x_train,y_train)
# Out:
# 1.0

# %%
knn.score(x_test,y_test)
# Out:
# 0.8815004603867248

# %%
y_test
# Out:
# 7836     False
# 2356     False
# 1030     False
# 16181     True
# 49487    False
#          ...
# 8365     False
# 8634     False
# 40515    False
# 18419    False
# 13423    False
# Name: hazardous, Length: 24979, dtype: bool

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 88.15004603867249

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.95      0.93     22251
#         True       0.45      0.36      0.40      2728
#
#     accuracy                           0.88     24979
#    macro avg       0.69      0.65      0.67     24979
# weighted avg       0.87      0.88      0.88     24979

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'C':[0.01,0.1,1,10,100],'penalty':['l1','l2']}
cls=GridSearchCV(log,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100], 'penalty': ['l1', 'l2']},
#              scoring='accuracy')

# %%
print(cls.best_params_)
# Out:
# {'C': 10, 'penalty': 'l2'}

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression(C=10,penalty='l2')
log.fit(x_train,y_train)
# Out:
# LogisticRegression(C=10, penalty='l2')

# %%
y_pred=log.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
log.score(x_train,y_train)
# Out:
# 0.8895872532927659

# %%
log.score(x_test,y_test)
# Out:
# 0.8903879258577205

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 89.03879258577206

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.90      0.99      0.94     22251
#         True       0.49      0.07      0.12      2728
#
#     accuracy                           0.89     24979
#    macro avg       0.69      0.53      0.53     24979
# weighted avg       0.85      0.89      0.85     24979

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'max_depth':[None,5,10,20,30],
    'min_samples_split':[2,5,10,20]}
cls=GridSearchCV(dt,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [None, 5, 10, 20, 30],
#                          'min_samples_split': [2, 5, 10, 20]},
#              scoring='accuracy')

# %%
print(cls.best_params_)
# Out:
# {'max_depth': 5, 'min_samples_split': 2}

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier(max_depth=10,min_samples_split=20)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_split=20)

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
dt.score(x_test,y_test)
# Out:
# 0.8766563913687497

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 87.66563913687497

# %%
print(classification_report(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.93      0.93     22251
#         True       0.44      0.43      0.43      2728
#
#     accuracy                           0.88     24979
#    macro avg       0.68      0.68      0.68     24979
# weighted avg       0.88      0.88      0.88     24979
#
# ...

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'n_estimators':[50,100,200],
    'max_depth':[None,10,20,30]}
cls=GridSearchCV(rf,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=RandomForestClassifier(n_estimators=47, random_state=34),
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
print(cls.best_params_)
# Out:
# {'max_depth': 20, 'n_estimators': 200}

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(max_depth=20,n_estimators=200)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 47,random_state=34)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
# Out:
# 0.9026382161015253

# %%
y_pred=rf.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
rf.score(x_train,y_train)
# Out:
# 0.9997998318587613

# %%
rf.score(x_test,y_test)
# Out:
# 0.9026382161015253

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.26382161015253

# %%
print(classification_report(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.96      0.95     22251
#         True       0.58      0.40      0.47      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.75      0.68      0.71     24979
# weighted avg       0.89      0.90      0.89     24979
#
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.93      0.96      0.95     22251
#         True       0.58      0.40      0.47      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.75      0.68      0.71     24979
# weighted avg       0.89      0.90      0.89     24979

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'n_estimators':[50,100,150,200,300],'learning_rate':[0.01,0.1,0.5,1]}
cls=GridSearchCV(adaboost,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=AdaBoostClassifier(learning_rate=0.3, random_state=1),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1],
#                          'n_estimators': [50, 100, 150, 200, 300]},
#              scoring='accuracy')

# %%
print(cls.best_params_)
# Out:
# {'learning_rate': 0.5, 'n_estimators': 300}

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost=AdaBoostClassifier(learning_rate=0.5,n_estimators=300)
adaboost.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.5, n_estimators=300)

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost=AdaBoostClassifier(n_estimators=50,estimator=None,learning_rate=0.3,random_state=1)

# %%
adaboost.fit(x_train,y_train)
y_pred=adaboost.predict(x_train)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
adaboost.score(x_train,y_train)
# Out:
# 0.889427118779775

# %%
adaboost.score(x_test,y_test)
# Out:
# 0.8907882621401978

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 89.07882621401978

# %%
print(classification_report(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      1.00      0.94     22251
#         True       0.00      0.00      0.00      2728
#
#     accuracy                           0.89     24979
#    macro avg       0.45      0.50      0.47     24979
# weighted avg       0.79      0.89      0.84     24979
#
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.89      1.00      0.94     22251
#         True       0.00      0.00      0.00      2728
#
#     accuracy                           0.89     24979
#    macro avg       0.45      0.50      0.47     24979
# weighted avg       0.79      0.89      0.84     24979

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'n_estimators':[100,200,300],
    'learning_rate':[0.01,0.1,0.2]}
cls=GridSearchCV(gbc,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=GradientBoostingClassifier(learning_rate=0.05,
#                                                   n_estimators=200,
#                                                   random_state=100),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy')

# %%
print(cls.best_params_)
# Out:
# {'learning_rate': 0.2, 'n_estimators': 300}

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(learning_rate=0.2,n_estimators=300)
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.2, n_estimators=300)

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc=GradientBoostingClassifier(n_estimators=200,learning_rate=0.05, random_state=100) 
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, n_estimators=200,
#                            random_state=100)

# %%
y_pred=gbc.predict(x_test)
y_pred
# Out:
# array([False, False, False, ..., False, False, False], shape=(24979,))

# %%
gbc.score(x_train,y_train)
# Out:
# 0.9038392249489571

# %%
gbc.score(x_test,y_test)
# Out:
# 0.902237879819048

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.2237879819048

# %%
print(classification_report(y_test,y_pred))
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.99      0.95     22251
#         True       0.76      0.15      0.26      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.83      0.57      0.60     24979
# weighted avg       0.89      0.90      0.87     24979
#
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.91      0.99      0.95     22251
#         True       0.76      0.15      0.26      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.83      0.57      0.60     24979
# weighted avg       0.89      0.90      0.87     24979

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
par={'n_estimators':[100,200,300],
    'learning_rate':[0.01,0.1,0.2]}
cls=GridSearchCV(xgb,par,cv=10,scoring='accuracy')
cls.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
# ...

# %%
print(cls.best_params_)
# Out:
# {'learning_rate': 0.01, 'n_estimators': 200}

# %%
from xgboost import XGBClassifier
xgb=XGBClassifier(learning_rate=0.01,n_estimators=200)
xgb.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.01, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
# !pip install xgboost
from xgboost import XGBClassifier
xgb=XGBClassifier()
xgb.fit(x_train,y_train)
# Out:
# ...
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred=xgb.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(24979,))

# %%
xgb.score(x_train,y_train)
# Out:
# 0.9370271027663237

# %%
xgb.score(x_test,y_test)
# Out:
# 0.9023179470755435

# %%
from sklearn.metrics import accuracy_score,ConfusionMatrixDisplay
print(accuracy_score(y_test,y_pred)*100)
# Out:
# 90.23179470755434

# %%
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.98      0.95     22251
#         True       0.61      0.29      0.40      2728
#
#     accuracy                           0.90     24979
#    macro avg       0.76      0.64      0.67     24979
# weighted avg       0.88      0.90      0.89     24979

# %%
import joblib
joblib.dump(xgb,r'C:\Users\ASUS\machine learning\NASA-Nearest Earth Objects.pkl')
joblib.dump(le1,r'C:\Users\ASUS\machine learning\le1.pkl')
joblib.dump(sd,r'C:\Users\ASUS\machine learning\sd.pkl')
# Out:
# ['C:\\Users\\ASUS\\machine learning\\sd.pkl']
